# %%
import boto3
import sagemaker 
from sagemaker import clarify

import os
from IPython.display import Image

role = sagemaker.get_execution_role()
sess = sagemaker.session.Session()

input_image_path = "s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/images_for_shapley/weather/"
bucket = "sagemaker-project-p-o3c1kiruwcnf"
model_name = 'weather-v3'
model_family = 'weather'
prefix = "bdd100k_images/predictions/shapley"
clarify_output_prefix = f"{prefix}/{model_name}"

model_labels = {
    "weather": [
        "rainy",
        "snowy", 
        "clear",
        "overcast",
        "partly cloudy",
        "undefined"
    ],
    "timeofday": [
        "daytime",
        "night",
        "dawn/dusk",
        "undefined"
    ],
    "scene": [
        "residential", 
        "city street",
        "highway",
        "undefined"
    ]
}

object_categories = model_labels[model_family]

explainability_data_config = clarify.DataConfig(
    s3_data_input_path=input_image_path,
    s3_output_path=f"s3://{bucket}/{clarify_output_prefix}",
    dataset_type="application/x-image",
)

model_config = clarify.ModelConfig(
    model_name=model_name, instance_type="ml.m5.xlarge", accelerator_type = 'ml.eia2.large', instance_count=1, content_type="image/jpeg"
)

predictions_config = clarify.ModelPredictedLabelConfig(label_headers=object_categories)

image_config = clarify.ImageConfig(
    model_type="IMAGE_CLASSIFICATION", num_segments=20, segment_compactness=5
)

shap_config = clarify.SHAPConfig(num_samples=500, image_config=image_config)
# Out:
# DataConfig will be deprecated on 15 Mar 2022.s3_data_distribution_type parameter will no longer be supported. Everything else will remain as is in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# # Run Clarify

# %%
clarify_processor = clarify.SageMakerClarifyProcessor(
    role=role, instance_count=1, instance_type="ml.m5.xlarge", sagemaker_session=sess
)

clarify_processor.run_explainability(
    data_config=explainability_data_config,
    model_config=model_config,
    explainability_config=shap_config,
    model_scores=predictions_config,
)
# Out:
# Job Name:  Clarify-Explainability-2022-06-03-16-52-04-235
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/images_for_shapley/weather/', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ..............................2022-06-03 16:56:52,188 logging.conf not found when configuring logging, using default logging configuration.
# 2022-06-03 16:56:52,190 Starting SageMaker Clarify Processing job
# 2022-06-03 16:56:52,190 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2022-06-03 16:56:52,190 Analysis result path: /opt/ml/processing/output
# 2022-06-03 16:56:52,190 This host is algo-1.
# 2022-06-03 16:56:52,190 This host is the leader.
# 2022-06-03 16:56:52,190 Number of hosts in the cluster is 1.
# 2022-06-03 16:56:52,464 Running Python based analyzer for images.
# 2022-06-03 16:56:52,465 Dataset uri: /opt/ml/processing/input/data
# 2022-06-03 16:56:52,465 Dataset type: application/x-image
# 2022-06-03 16:56:52,518 Spinning up shadow endpoint
# 2022-06-03 16:56:52,518 Creating endpoint-config with name sm-clarify-config-1654275412-b996
# 2022-06-03 16:56:52,595 Creating endpoint: 'sm-clarify-weather-v3-1654275412-10c3'
# 2022-06-03 16:56:52,860 =====================================================
# 2022-06-03 16:56:52,860 SHAP analyzer: explaining images
# 2022-06-03 16:56:52,860 =====================================================
# 2022-06-03 16:56:52,860 Processing image '/opt/ml/processing/input/data/c8c0c00c-5a90317a.jpg'
# 2022-06-03 16:56:54,113 Image '/opt/ml/processing/input/data/c8c0c00c-5a90317a.jpg' segmented into 10 pieces
# 2022-06-03 16:56:54,114 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2022-06-03 17:03:55,025 Endpoint is in service after 421 seconds
# 2022-06-03 17:04:00,533 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:04:43,905 getting explanations took 43.21 seconds.
# 2022-06-03 17:04:43,905 ===================================================
# 2022-06-03 17:04:44,588 Processing image '/opt/ml/processing/input/data/be5c5aae-d31145ff.jpg'
# 2022-06-03 17:04:45,838 Image '/opt/ml/processing/input/data/be5c5aae-d31145ff.jpg' segmented into 12 pieces
# 2022-06-03 17:04:45,904 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:05:30,268 getting explanations took 44.21 seconds.
# 2022-06-03 17:05:30,268 ===================================================
# 2022-06-03 17:05:30,984 Processing image '/opt/ml/processing/input/data/b23bb45f-ddeea1d8.jpg'
# 2022-06-03 17:05:32,256 Image '/opt/ml/processing/input/data/b23bb45f-ddeea1d8.jpg' segmented into 10 pieces
# 2022-06-03 17:05:32,322 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:06:13,173 getting explanations took 40.73 seconds.
# 2022-06-03 17:06:13,173 ===================================================
# 2022-06-03 17:06:13,926 Processing image '/opt/ml/processing/input/data/c1b16eee-d45c1777.jpg'
# 2022-06-03 17:06:15,221 Image '/opt/ml/processing/input/data/c1b16eee-d45c1777.jpg' segmented into 13 pieces
# 2022-06-03 17:06:15,286 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:07:00,090 getting explanations took 44.66 seconds.
# 2022-06-03 17:07:00,090 ===================================================
# 2022-06-03 17:07:00,740 Processing image '/opt/ml/processing/input/data/b8fb5451-6c0e5ec6.jpg'
# 2022-06-03 17:07:01,977 Image '/opt/ml/processing/input/data/b8fb5451-6c0e5ec6.jpg' segmented into 9 pieces
# 2022-06-03 17:07:02,040 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:07:44,206 getting explanations took 42.03 seconds.
# 2022-06-03 17:07:44,206 ===================================================
# 2022-06-03 17:07:44,916 Processing image '/opt/ml/processing/input/data/b43bcc83-c97d569e.jpg'
# 2022-06-03 17:07:46,118 Image '/opt/ml/processing/input/data/b43bcc83-c97d569e.jpg' segmented into 12 pieces
# 2022-06-03 17:07:46,182 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:08:31,241 getting explanations took 44.84 seconds.
# 2022-06-03 17:08:31,241 ===================================================
# 2022-06-03 17:08:31,897 Processing image '/opt/ml/processing/input/data/c60deb3c-d8219cc9.jpg'
# 2022-06-03 17:08:33,119 Image '/opt/ml/processing/input/data/c60deb3c-d8219cc9.jpg' segmented into 13 pieces
# 2022-06-03 17:08:33,306 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:09:18,547 getting explanations took 45.10 seconds.
# 2022-06-03 17:09:18,548 ===================================================
# 2022-06-03 17:09:19,204 Processing image '/opt/ml/processing/input/data/b74ca6c1-38f5c3c8.jpg'
# 2022-06-03 17:09:20,421 Image '/opt/ml/processing/input/data/b74ca6c1-38f5c3c8.jpg' segmented into 12 pieces
# 2022-06-03 17:09:20,483 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:10:04,460 getting explanations took 43.81 seconds.
# 2022-06-03 17:10:04,460 ===================================================
# 2022-06-03 17:10:05,129 Processing image '/opt/ml/processing/input/data/c8f1cdd6-9d2a3186.jpg'
# 2022-06-03 17:10:06,360 Image '/opt/ml/processing/input/data/c8f1cdd6-9d2a3186.jpg' segmented into 10 pieces
# 2022-06-03 17:10:06,424 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:10:48,972 getting explanations took 42.42 seconds.
# 2022-06-03 17:10:48,973 ===================================================
# 2022-06-03 17:10:49,632 Processing image '/opt/ml/processing/input/data/be85bd88-d849c034.jpg'
# 2022-06-03 17:10:50,860 Image '/opt/ml/processing/input/data/be85bd88-d849c034.jpg' segmented into 13 pieces
# 2022-06-03 17:10:50,929 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to notebook
# [NbConvertApp] WARNING | Kernelspec name python3 cannot be found!
# [NbConvertApp] ERROR | No such kernel named python3
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 75, in wrapper
#     out = await method(self, *args, **kwargs)
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 383, in _async_start_kernel
#     kernel_cmd, kw = await ensure_async(self.pre_start_kernel(**kw))
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/utils.py", line 38, in ensure_async
#     return await obj
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 346, in _async_pre_start_kernel
#     self.kernel_spec,
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 176, in kernel_spec
#     self._kernel_spec = self.kernel_spec_manager.get_kernel_spec(self.kernel_name)
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/kernelspec.py", line 294, in get_kernel_spec
#     raise NoSuchKernel(kernel_name)
# jupyter_client.kernelspec.NoSuchKernel: No such kernel named python3
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-nbconvert", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/site-packages/jupyter_core/application.py", line 269, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "/usr/local/lib/python3.9/site-packages/traitlets/config/application.py", line 972, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 541, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 506, in convert_single_notebook
#     output, resources = self.export_single_notebook(notebook_filename, resources, input_buffer=input_buffer)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 435, in export_single_notebook
#     output, resources = self.exporter.from_filename(notebook_filename, resources=resources)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 190, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 208, in from_file
#     return self.from_notebook_node(nbformat.read(file_stream, as_version=4), resources=resources, **kw)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/exporters/notebook.py", line 32, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 147, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 334, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/preprocessors/base.py", line 47, in __call__
#     return self.preprocess(nb, resources)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/preprocessors/execute.py", line 79, in preprocess
#     with self.setup_kernel():
#   File "/usr/local/lib/python3.9/contextlib.py", line 119, in __enter__
#     return next(self.gen)
#   File "/usr/local/lib/python3.9/site-packages/nbclient/client.py", line 561, in setup_kernel
#     self.start_new_kernel(**kwargs)
#   File "/usr/local/lib/python3.9/site-packages/nbclient/util.py", line 84, in wrapped
#     return just_run(coro(*args, **kwargs))
#   File "/usr/local/lib/python3.9/site-packages/nbclient/util.py", line 62, in just_run
#     return loop.run_until_complete(coro)
#   File "/usr/local/lib/python3.9/asyncio/base_events.py", line 647, in run_until_complete
#     return future.result()
#   File "/usr/local/lib/python3.9/site-packages/nbclient/client.py", line 516, in async_start_new_kernel
#     await ensure_async(self.km.start_kernel(extra_arguments=self.extra_arguments, **kwargs))
#   File "/usr/local/lib/python3.9/site-packages/nbclient/util.py", line 96, in ensure_async
#     result = await obj
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 83, in wrapper
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 75, in wrapper
#     out = await method(self, *args, **kwargs)
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 383, in _async_start_kernel
#     kernel_cmd, kw = await ensure_async(self.pre_start_kernel(**kw))
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/utils.py", line 38, in ensure_async
#     return await obj
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 346, in _async_pre_start_kernel
#     self.kernel_spec,
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 176, in kernel_spec
#     self._kernel_spec = self.kernel_spec_manager.get_kernel_spec(self.kernel_name)
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/kernelspec.py", line 294, in get_kernel_spec
#     raise NoSuchKernel(kernel_name)
# jupyter_client.kernelspec.NoSuchKernel: No such kernel named python3
# 2022-06-03 17:13:06,478 Notebook did not execute successfully
# 2022-06-03 17:13:06,478 ['jupyter', 'nbconvert', "-TagRemovePreprocessor.remove_input_tags='remove_input'", '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'lab']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 576379 bytes to /opt/ml/processing/output/report.html
# 2022-06-03 17:13:07,397 ['/usr/local/bin/wkhtmltopdf', '-q', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2022-06-03 17:13:08,052 Generating image explanations PDF Reports took 2.58 seconds.
# 2022-06-03 17:13:08,052 ===================================================
# 2022-06-03 17:13:08,052 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# -------!

# %% [markdown]
# # Review Results

# %%
s3_client = boto3.client('s3')
output_objects = s3_client.list_objects(Bucket=bucket, Prefix=clarify_output_prefix)

result_images = []
for file_obj in output_objects["Contents"]:
    file_name = os.path.basename(file_obj["Key"])
    if os.path.splitext(file_name)[1] == ".jpeg":
        result_images.append(file_name)

    print(f"Downloading s3://{bucket}/{file_obj['Key']} ...")
    s3_client.download_file(bucket, file_obj["Key"], file_name)

for img in result_images:
    display(Image(img))
# Out:
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/analysis_config.json ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/report.html ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/report.ipynb ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/report.pdf ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_b23bb45f-ddeea1d8.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_b43bcc83-c97d569e.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_b74ca6c1-38f5c3c8.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_b7d13f97-0aec1868.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_b8fb5451-6c0e5ec6.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_be5c5aae-d31145ff.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_be85bd88-d849c034.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_c1b16eee-d45c1777.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_c60deb3c-d8219cc9.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_c8c0c00c-5a90317a.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_c8f1cdd6-9d2a3186.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/weather-v3/shap_ca656c47-876ad414.jpeg ...
