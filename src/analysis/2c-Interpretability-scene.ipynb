# %%
import boto3
import sagemaker 
from sagemaker import clarify

import os
from IPython.display import Image

role = sagemaker.get_execution_role()
sess = sagemaker.session.Session()

input_image_path = "s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/images_for_shapley/scene/"
bucket = "sagemaker-project-p-o3c1kiruwcnf"
model_name = 'scene-v3'
model_family = 'scene'
prefix = "bdd100k_images/predictions/shapley"
clarify_output_prefix = f"{prefix}/{model_name}"

model_labels = {
    "weather": [
        "rainy",
        "snowy", 
        "clear",
        "overcast",
        "partly cloudy",
        "undefined"
    ],
    "timeofday": [
        "daytime",
        "night",
        "dawn/dusk",
        "undefined"
    ],
    "scene": [
        "residential", 
        "city street",
        "highway",
        "undefined"
    ]
}

object_categories = model_labels[model_family]

explainability_data_config = clarify.DataConfig(
    s3_data_input_path=input_image_path,
    s3_output_path=f"s3://{bucket}/{clarify_output_prefix}",
    dataset_type="application/x-image",
)

model_config = clarify.ModelConfig(
    model_name=model_name, instance_type="ml.m5.xlarge", accelerator_type = 'ml.eia2.large', instance_count=1, content_type="image/jpeg"
)

predictions_config = clarify.ModelPredictedLabelConfig(label_headers=object_categories)

image_config = clarify.ImageConfig(
    model_type="IMAGE_CLASSIFICATION", num_segments=20, segment_compactness=5
)

shap_config = clarify.SHAPConfig(num_samples=500, image_config=image_config)
# Out:
# DataConfig will be deprecated on 15 Mar 2022.s3_data_distribution_type parameter will no longer be supported. Everything else will remain as is in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# # Run Clarify

# %%
clarify_processor = clarify.SageMakerClarifyProcessor(
    role=role, instance_count=1, instance_type="ml.m5.xlarge", sagemaker_session=sess
)

clarify_processor.run_explainability(
    data_config=explainability_data_config,
    model_config=model_config,
    explainability_config=shap_config,
    model_scores=predictions_config,
)
# Out:
# Job Name:  Clarify-Explainability-2022-06-03-16-51-37-214
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/images_for_shapley/scene/', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ..............................2022-06-03 16:56:25,805 logging.conf not found when configuring logging, using default logging configuration.
# 2022-06-03 16:56:25,807 Starting SageMaker Clarify Processing job
# 2022-06-03 16:56:25,807 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2022-06-03 16:56:25,808 Analysis result path: /opt/ml/processing/output
# 2022-06-03 16:56:25,808 This host is algo-1.
# 2022-06-03 16:56:25,808 This host is the leader.
# 2022-06-03 16:56:25,808 Number of hosts in the cluster is 1.
# 2022-06-03 16:56:26,080 Running Python based analyzer for images.
# 2022-06-03 16:56:26,081 Dataset uri: /opt/ml/processing/input/data
# 2022-06-03 16:56:26,081 Dataset type: application/x-image
# 2022-06-03 16:56:26,134 Spinning up shadow endpoint
# 2022-06-03 16:56:26,135 Creating endpoint-config with name sm-clarify-config-1654275386-51ed
# 2022-06-03 16:56:26,234 Creating endpoint: 'sm-clarify-scene-v3-1654275386-860c'
# 2022-06-03 16:56:26,501 =====================================================
# 2022-06-03 16:56:26,501 SHAP analyzer: explaining images
# 2022-06-03 16:56:26,501 =====================================================
# 2022-06-03 16:56:26,502 Processing image '/opt/ml/processing/input/data/bd6dcefc-68d695b9.jpg'
# 2022-06-03 16:56:27,601 Image '/opt/ml/processing/input/data/bd6dcefc-68d695b9.jpg' segmented into 15 pieces
# 2022-06-03 16:56:27,602 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2022-06-03 17:02:28,411 Endpoint is in service after 361 seconds
# 2022-06-03 17:02:33,846 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:03:21,730 getting explanations took 47.72 seconds.
# 2022-06-03 17:03:21,731 ===================================================
# 2022-06-03 17:03:22,404 Processing image '/opt/ml/processing/input/data/ba7efc39-e3e9eecf.jpg'
# 2022-06-03 17:03:23,582 Image '/opt/ml/processing/input/data/ba7efc39-e3e9eecf.jpg' segmented into 10 pieces
# 2022-06-03 17:03:23,644 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:04:06,171 getting explanations took 42.39 seconds.
# 2022-06-03 17:04:06,171 ===================================================
# 2022-06-03 17:04:06,838 Processing image '/opt/ml/processing/input/data/b1d0a191-de8948f6.jpg'
# 2022-06-03 17:04:08,082 Image '/opt/ml/processing/input/data/b1d0a191-de8948f6.jpg' segmented into 10 pieces
# 2022-06-03 17:04:08,143 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:04:51,200 getting explanations took 42.93 seconds.
# 2022-06-03 17:04:51,200 ===================================================
# 2022-06-03 17:04:51,919 Processing image '/opt/ml/processing/input/data/b43de6e1-f20e4351.jpg'
# 2022-06-03 17:04:53,002 Image '/opt/ml/processing/input/data/b43de6e1-f20e4351.jpg' segmented into 15 pieces
# 2022-06-03 17:04:53,064 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:05:40,756 getting explanations took 47.54 seconds.
# 2022-06-03 17:05:40,756 ===================================================
# 2022-06-03 17:05:41,474 Processing image '/opt/ml/processing/input/data/c1715aef-9c4e4c40.jpg'
# 2022-06-03 17:05:42,693 Image '/opt/ml/processing/input/data/c1715aef-9c4e4c40.jpg' segmented into 12 pieces
# 2022-06-03 17:05:42,755 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:06:27,354 getting explanations took 44.46 seconds.
# 2022-06-03 17:06:27,355 ===================================================
# 2022-06-03 17:06:28,015 Processing image '/opt/ml/processing/input/data/bb8dba97-3537805c.jpg'
# 2022-06-03 17:06:29,244 Image '/opt/ml/processing/input/data/bb8dba97-3537805c.jpg' segmented into 12 pieces
# 2022-06-03 17:06:29,305 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:07:14,037 getting explanations took 44.59 seconds.
# 2022-06-03 17:07:14,037 ===================================================
# 2022-06-03 17:07:14,701 Processing image '/opt/ml/processing/input/data/c11a0015-fa2086af.jpg'
# 2022-06-03 17:07:15,951 Image '/opt/ml/processing/input/data/c11a0015-fa2086af.jpg' segmented into 10 pieces
# 2022-06-03 17:07:16,016 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:07:59,275 getting explanations took 43.12 seconds.
# 2022-06-03 17:07:59,275 ===================================================
# 2022-06-03 17:07:59,953 Processing image '/opt/ml/processing/input/data/ba36b0a9-6c380330.jpg'
# 2022-06-03 17:08:01,163 Image '/opt/ml/processing/input/data/ba36b0a9-6c380330.jpg' segmented into 15 pieces
# 2022-06-03 17:08:01,227 SHAP n_samples 500
#   0% (0 of 1) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--
# 100% (1 of 1) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 2022-06-03 17:08:49,159 getting explanations took 47.78 seconds.
# 2022-06-03 17:08:49,159 ===================================================
# 2022-06-03 17:08:49,894 SHAP analysis finished.
# 2022-06-03 17:08:49,894 Successfully analyzed images. Input_Output_image_map: {'/opt/ml/processing/input/data/bd6dcefc-68d695b9.jpg': ['/opt/ml/processing/output/shap_bd6dcefc-68d695b9.jpeg'], '/opt/ml/processing/input/data/ba7efc39-e3e9eecf.jpg': ['/opt/ml/processing/output/shap_ba7efc39-e3e9eecf.jpeg'], '/opt/ml/processing/input/data/b1d0a191-de8948f6.jpg': ['/opt/ml/processing/output/shap_b1d0a191-de8948f6.jpeg'], '/opt/ml/processing/input/data/b43de6e1-f20e4351.jpg': ['/opt/ml/processing/output/shap_b43de6e1-f20e4351.jpeg'], '/opt/ml/processing/input/data/c1715aef-9c4e4c40.jpg': ['/opt/ml/processing/output/shap_c1715aef-9c4e4c40.jpeg'], '/opt/ml/processing/input/data/bb8dba97-3537805c.jpg': ['/opt/ml/processing/output/shap_bb8dba97-3537805c.jpeg'], '/opt/ml/processing/input/data/c11a0015-fa2086af.jpg': ['/opt/ml/processing/output/shap_c11a0015-fa2086af.jpeg'], '/opt/ml/processing/input/data/ba36b0a9-6c380330.jpg': ['/opt/ml/processing/output/shap_ba36b0a9-6c380330.jpeg']}
# 2022-06-03 17:08:49,894 Stop using endpoint: sm-clarify-scene-v3-1654275386-860c
# 2022-06-03 17:08:49,894 Deleting endpoint configuration with name: sm-clarify-config-1654275386-51ed
# 2022-06-03 17:08:50,071 Deleting endpoint with name: sm-clarify-scene-v3-1654275386-860c
# 2022-06-03 17:08:50,200 Model endpoint delivered 5.30561 requests per second and a total of 2024 requests over 381 seconds
# 2022-06-03 17:08:50,200 Stop using endpoint: None
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to notebook
# [NbConvertApp] WARNING | Kernelspec name python3 cannot be found!
# [NbConvertApp] ERROR | No such kernel named python3
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 75, in wrapper
#     out = await method(self, *args, **kwargs)
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 383, in _async_start_kernel
#     kernel_cmd, kw = await ensure_async(self.pre_start_kernel(**kw))
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/utils.py", line 38, in ensure_async
#     return await obj
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 346, in _async_pre_start_kernel
#     self.kernel_spec,
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 176, in kernel_spec
#     self._kernel_spec = self.kernel_spec_manager.get_kernel_spec(self.kernel_name)
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/kernelspec.py", line 294, in get_kernel_spec
#     raise NoSuchKernel(kernel_name)
# jupyter_client.kernelspec.NoSuchKernel: No such kernel named python3
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-nbconvert", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.9/site-packages/jupyter_core/application.py", line 269, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "/usr/local/lib/python3.9/site-packages/traitlets/config/application.py", line 972, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 369, in start
#     self.convert_notebooks()
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 541, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 506, in convert_single_notebook
#     output, resources = self.export_single_notebook(notebook_filename, resources, input_buffer=input_buffer)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 435, in export_single_notebook
#     output, resources = self.exporter.from_filename(notebook_filename, resources=resources)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 190, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 208, in from_file
#     return self.from_notebook_node(nbformat.read(file_stream, as_version=4), resources=resources, **kw)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/exporters/notebook.py", line 32, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 147, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 334, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/preprocessors/base.py", line 47, in __call__
#     return self.preprocess(nb, resources)
#   File "/usr/local/lib/python3.9/site-packages/nbconvert/preprocessors/execute.py", line 79, in preprocess
#     with self.setup_kernel():
#   File "/usr/local/lib/python3.9/contextlib.py", line 119, in __enter__
#     return next(self.gen)
#   File "/usr/local/lib/python3.9/site-packages/nbclient/client.py", line 561, in setup_kernel
#     self.start_new_kernel(**kwargs)
#   File "/usr/local/lib/python3.9/site-packages/nbclient/util.py", line 84, in wrapped
#     return just_run(coro(*args, **kwargs))
#   File "/usr/local/lib/python3.9/site-packages/nbclient/util.py", line 62, in just_run
#     return loop.run_until_complete(coro)
#   File "/usr/local/lib/python3.9/asyncio/base_events.py", line 647, in run_until_complete
#     return future.result()
#   File "/usr/local/lib/python3.9/site-packages/nbclient/client.py", line 516, in async_start_new_kernel
#     await ensure_async(self.km.start_kernel(extra_arguments=self.extra_arguments, **kwargs))
#   File "/usr/local/lib/python3.9/site-packages/nbclient/util.py", line 96, in ensure_async
#     result = await obj
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 83, in wrapper
#     raise e
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 75, in wrapper
#     out = await method(self, *args, **kwargs)
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 383, in _async_start_kernel
#     kernel_cmd, kw = await ensure_async(self.pre_start_kernel(**kw))
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/utils.py", line 38, in ensure_async
#     return await obj
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 346, in _async_pre_start_kernel
#     self.kernel_spec,
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/manager.py", line 176, in kernel_spec
#     self._kernel_spec = self.kernel_spec_manager.get_kernel_spec(self.kernel_name)
#   File "/usr/local/lib/python3.9/site-packages/jupyter_client/kernelspec.py", line 294, in get_kernel_spec
#     raise NoSuchKernel(kernel_name)
# jupyter_client.kernelspec.NoSuchKernel: No such kernel named python3
# 2022-06-03 17:08:51,253 Notebook did not execute successfully
# 2022-06-03 17:08:51,253 ['jupyter', 'nbconvert', "-TagRemovePreprocessor.remove_input_tags='remove_input'", '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'lab']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 575987 bytes to /opt/ml/processing/output/report.html
# 2022-06-03 17:08:52,203 ['/usr/local/bin/wkhtmltopdf', '-q', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2022-06-03 17:08:52,864 Generating image explanations PDF Reports took 2.66 seconds.
# 2022-06-03 17:08:52,864 ===================================================
# 2022-06-03 17:08:52,864 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# ------!

# %% [markdown]
# # Review Results

# %%
s3_client = boto3.client('s3')
output_objects = s3_client.list_objects(Bucket=bucket, Prefix=clarify_output_prefix)

result_images = []
for file_obj in output_objects["Contents"]:
    file_name = os.path.basename(file_obj["Key"])
    if os.path.splitext(file_name)[1] == ".jpeg":
        result_images.append(file_name)

    print(f"Downloading s3://{bucket}/{file_obj['Key']} ...")
    s3_client.download_file(bucket, file_obj["Key"], file_name)

for img in result_images:
    display(Image(img))
# Out:
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/analysis_config.json ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/report.html ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/report.ipynb ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/report.pdf ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/shap_b1d0a191-de8948f6.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/shap_b43de6e1-f20e4351.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/shap_ba36b0a9-6c380330.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/shap_ba7efc39-e3e9eecf.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/shap_bb8dba97-3537805c.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/shap_bd6dcefc-68d695b9.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/shap_c11a0015-fa2086af.jpeg ...
# Downloading s3://sagemaker-project-p-o3c1kiruwcnf/bdd100k_images/predictions/shapley/scene-v3/shap_c1715aef-9c4e4c40.jpeg ...
